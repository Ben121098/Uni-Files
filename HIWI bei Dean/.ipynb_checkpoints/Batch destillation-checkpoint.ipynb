# %%
import do_mpc
import numpy as np
from Kolonne_8_Boeden import template_model
from Kolonne_8_Boeden import template_simulator

# %% [markdown]
# Build model and simulator using template functions

# %%
model = template_model()
simulator = template_simulator(model)

params_simulator = {
    "integration_tool": "idas",
    "abstol": 1e-10,
    "reltol": 1e-10,
    "t_step": 0.005,
}
simulator.set_param(**params_simulator)
simulator.setup()
simulator.set_initial_guess()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['font.size'] = 18
mpl.rcParams['lines.linewidth'] = 3
mpl.rcParams['axes.grid'] = True

# %%
sim_graphics = do_mpc.graphics.Graphics(simulator.data)
fig, ax = plt.subplots(2, sharex=True)
g.add_line(var_type='_x', var_name='e0_HU_st2_i2', axis=ax[0])
g.add_line(var_type='_x', var_name='e0_HU_st4_i2', axis=ax[0])
g.add_line(var_type='_x', var_name='e0_HU_st7_i2', axis=ax[0])
